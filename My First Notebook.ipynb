# %%
1 + 1
# Out:
# 2

# %%
1 / 1000
# Out:
# 0.001

# %%
x = 1 + 1

# %%
y = x**2

# %%
z = y - z
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-f22a5137fce6> in <module>
# ----> 1 z = y - z
#
# NameError: name 'z' is not defined

# %%
int z
# Out:
#   File "<ipython-input-6-847622c0320b>", line 1
#     int z
#         ^
# SyntaxError: invalid syntax

# %%
z = y - x

# %%
print(z)
# Out:
# 2

# %% [markdown]
# # Lab - IBM Watson Studio

# %% [markdown]
# ### Adding Notebooks to your Project on Watson Studio

# %% [markdown]
# * Creating an Account on Watson Studio
# * Create your first Project on Watson Studio

# %% [markdown]
# * Adding Notebooks to your Project on Watson Studio
#     * Following the videos within this week, create your first notebook within "My First Project".

# %% [markdown]
# ![alt text](https://venturebeat.com/wp-content/uploads/2015/05/Witcher-3-logos-e1432902911819.png?fit=578%2C274&strip=all "Witcher 3")
