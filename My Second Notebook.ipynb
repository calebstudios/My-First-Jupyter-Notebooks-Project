# %%
1 + 1
# Out:
# 2

# %%
22 / 7
# Out:
# 3.142857142857143

# %%
(22/7)**2
# Out:
# 9.877551020408163

# %%
(22 / 7)**2
# Out:
# 9.877551020408163

# %%
(22 / 7) + (22 / 7)
# Out:
# 6.285714285714286

# %%
10 * 2
# Out:
# 20

# %%
(10 * 100) / 22
# Out:
# 45.45454545454545

# %%
(10 * 100) / 7
# Out:
# 142.85714285714286

# %%
1 * 2 * 3 * 4 * 5 * 6 * 7 * 8 * 9
# Out:
# 362880

# %%
11 * 22 * 33 * 44 * 55
# Out:
# 19326120

# %%
1111111111 * 111111111
# Out:
# 123456789987654321

# %%
12 * 34 * 56 * 78 * 90 * 11111
# Out:
# 1782126178560

# %% [markdown]
# # My Title

# %% [markdown]
# ## Heading 1

# %% [markdown]
# ### Heading 2

# %% [markdown]
# #### Heading 3

# %% [markdown]
# My Title

# %% [markdown]
# ##### Heading 4

# %% [markdown]
# \*literal asterisks*\

# %% [markdown]
# \*literal asterisks\*

# %% [markdown]
# *literal asterisks*

# %% [markdown]
# def f(x):
#     """a docstring***
#     return x**2

# %%
def f(x):
    """a docstring"""
    return x**2

# %%
(22/7)**2
# Out:
# 9.877551020408163

# %%
2**2
# Out:
# 4
